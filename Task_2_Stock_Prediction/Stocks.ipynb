# %% [markdown]
# #  STOCK PREDICTION

# %% [markdown]
# ## STEP 1 : IMPORTING LIBRARIES AND DATA TO BE USED

# %%
#importing libraries to be used
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('Stocks_Dataset.csv') # data_importing
df.head(10) # fetching first 10 rows of dataset
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %% [markdown]
# ## STEP 2 : GATHERING INSIGHTS

# %%
# shape of data
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
# statistical description of data
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
# summary of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
# checking null values
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %% [markdown]
# ### There are no null values in the dataset

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %% [markdown]
# ## STEP 3 : DATA PRE-PROCESSING

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %% [markdown]
# ## STEP 4 :  CREATING LSTM MODEL

# %%
# imported Sequential from keras.models
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 50, 50)            10600
#
#  dropout_2 (Dropout)         (None, 50, 50)            0
#
#  lstm_5 (LSTM)               (None, 50)                20200
#
#  dense_2 (Dense)             (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 8s 78ms/step - loss: 0.0102 - mean_absolute_error: 0.0701 - val_loss: 0.0174 - val_mean_absolute_error: 0.1073
# Epoch 2/100
# 28/28 [==============================] - 1s 45ms/step - loss: 8.6347e-04 - mean_absolute_error: 0.0235 - val_loss: 0.0042 - val_mean_absolute_error: 0.0509
# Epoch 3/100
# 28/28 [==============================] - 1s 46ms/step - loss: 4.9749e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0019 - val_mean_absolute_error: 0.0338
# Epoch 4/100
# 28/28 [==============================] - 1s 46ms/step - loss: 4.4834e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0030 - val_mean_absolute_error: 0.0420
# Epoch 5/100
# 28/28 [==============================] - 1s 48ms/step - loss: 4.2997e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0030 - val_mean_absolute_error: 0.0415
# Epoch 6/100
# 28/28 [==============================] - 1s 48ms/step - loss: 4.7808e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0023 - val_mean_absolute_error: 0.0366
# Epoch 7/100
# 28/28 [==============================] - 2s 73ms/step - loss: 4.3161e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0027 - val_mean_absolute_error: 0.0393
# Epoch 8/100
# 28/28 [==============================] - 2s 64ms/step - loss: 4.3154e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0044 - val_mean_absolute_error: 0.0525
# Epoch 9/100
# 28/28 [==============================] - 1s 46ms/step - loss: 4.1571e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0042 - val_mean_absolute_error: 0.0509
# Epoch 10/100
# 28/28 [==============================] - 1s 45ms/step - loss: 4.0712e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0038 - val_mean_absolute_error: 0.0478
# Epoch 11/100
# 28/28 [==============================] - 1s 46ms/step - loss: 4.0080e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0034 - val_mean_absolute_error: 0.0444
# Epoch 12/100
# 28/28 [==============================] - 1s 45ms/step - loss: 3.8965e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0028 - val_mean_absolute_error: 0.0400
# Epoch 13/100
# 28/28 [==============================] - 1s 45ms/step - loss: 4.1654e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0039 - val_mean_absolute_error: 0.0483
# Epoch 14/100
# 28/28 [==============================] - 1s 45ms/step - loss: 3.5380e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0035 - val_mean_absolute_error: 0.0454
# Epoch 15/100
# 28/28 [==============================] - 2s 62ms/step - loss: 3.5125e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0045 - val_mean_absolute_error: 0.0536
# Epoch 16/100
# 28/28 [==============================] - 3s 119ms/step - loss: 3.6465e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0026 - val_mean_absolute_error: 0.0378
# Epoch 17/100
# 28/28 [==============================] - 2s 55ms/step - loss: 3.8734e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0041 - val_mean_absolute_error: 0.0500
# Epoch 18/100
# 28/28 [==============================] - 1s 47ms/step - loss: 3.6979e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0036 - val_mean_absolute_error: 0.0465
# Epoch 19/100
# 28/28 [==============================] - 1s 46ms/step - loss: 3.1187e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0061 - val_mean_absolute_error: 0.0638
# Epoch 20/100
# 28/28 [==============================] - 1s 47ms/step - loss: 3.2370e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0024 - val_mean_absolute_error: 0.0368
# Epoch 21/100
# 28/28 [==============================] - 1s 46ms/step - loss: 3.3081e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0055 - val_mean_absolute_error: 0.0603
# Epoch 22/100
# 28/28 [==============================] - 1s 45ms/step - loss: 3.4837e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0049 - val_mean_absolute_error: 0.0560
# Epoch 23/100
# 28/28 [==============================] - 1s 46ms/step - loss: 3.3967e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0028 - val_mean_absolute_error: 0.0397
# Epoch 24/100
# 28/28 [==============================] - 2s 54ms/step - loss: 3.1648e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0073 - val_mean_absolute_error: 0.0717
# Epoch 25/100
# 28/28 [==============================] - 2s 78ms/step - loss: 3.0876e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0040 - val_mean_absolute_error: 0.0502
# Epoch 26/100
# 28/28 [==============================] - 1s 47ms/step - loss: 3.0417e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0043 - val_mean_absolute_error: 0.0519
# Epoch 27/100
# 28/28 [==============================] - 1s 47ms/step - loss: 2.9617e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0050 - val_mean_absolute_error: 0.0568
# Epoch 28/100
# 28/28 [==============================] - 1s 49ms/step - loss: 2.8834e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0024 - val_mean_absolute_error: 0.0360
# Epoch 29/100
# 28/28 [==============================] - 1s 46ms/step - loss: 3.1822e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0050 - val_mean_absolute_error: 0.0573
# Epoch 30/100
# 28/28 [==============================] - 1s 46ms/step - loss: 2.8677e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0045 - val_mean_absolute_error: 0.0530
# Epoch 31/100
# 28/28 [==============================] - 1s 45ms/step - loss: 2.7752e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0037 - val_mean_absolute_error: 0.0469
# Epoch 32/100
# 28/28 [==============================] - 1s 46ms/step - loss: 2.6158e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0036 - val_mean_absolute_error: 0.0459
# Epoch 33/100
# 28/28 [==============================] - 1s 52ms/step - loss: 2.7024e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0046 - val_mean_absolute_error: 0.0538
# Epoch 34/100
# 28/28 [==============================] - 2s 78ms/step - loss: 2.5416e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0028 - val_mean_absolute_error: 0.0391
# Epoch 35/100
# 28/28 [==============================] - 1s 50ms/step - loss: 2.6052e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0060 - val_mean_absolute_error: 0.0631
# Epoch 36/100
# 28/28 [==============================] - 1s 46ms/step - loss: 2.5620e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0045 - val_mean_absolute_error: 0.0530
# Epoch 37/100
# 28/28 [==============================] - 1s 46ms/step - loss: 2.7588e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0044 - val_mean_absolute_error: 0.0522
# Epoch 38/100
# 28/28 [==============================] - 1s 46ms/step - loss: 2.3672e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0030 - val_mean_absolute_error: 0.0417
# Epoch 39/100
# 28/28 [==============================] - 1s 49ms/step - loss: 2.4933e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0061 - val_mean_absolute_error: 0.0642
# Epoch 40/100
# 28/28 [==============================] - 1s 47ms/step - loss: 2.7073e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0067 - val_mean_absolute_error: 0.0691
# Epoch 41/100
# 28/28 [==============================] - 1s 46ms/step - loss: 2.6646e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0018 - val_mean_absolute_error: 0.0313
# Epoch 42/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.2561e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0039 - val_mean_absolute_error: 0.0498
# Epoch 43/100
# 28/28 [==============================] - 4s 130ms/step - loss: 2.2488e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0017 - val_mean_absolute_error: 0.0299
# Epoch 44/100
# 28/28 [==============================] - 3s 94ms/step - loss: 2.4060e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0034 - val_mean_absolute_error: 0.0448
# Epoch 45/100
# 28/28 [==============================] - 1s 46ms/step - loss: 2.2736e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0046 - val_mean_absolute_error: 0.0547
# Epoch 46/100
# 28/28 [==============================] - 1s 46ms/step - loss: 2.1874e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0029 - val_mean_absolute_error: 0.0414
# Epoch 47/100
# 28/28 [==============================] - 1s 47ms/step - loss: 2.2419e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0021 - val_mean_absolute_error: 0.0339
# Epoch 48/100
# 28/28 [==============================] - 1s 46ms/step - loss: 2.2450e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0015 - val_mean_absolute_error: 0.0282
# Epoch 49/100
# 28/28 [==============================] - 1s 46ms/step - loss: 2.0920e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0017 - val_mean_absolute_error: 0.0298
# Epoch 50/100
# 28/28 [==============================] - 2s 59ms/step - loss: 2.0879e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0035 - val_mean_absolute_error: 0.0466
# Epoch 51/100
# 28/28 [==============================] - 2s 75ms/step - loss: 1.9234e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0025 - val_mean_absolute_error: 0.0380
# Epoch 52/100
# 28/28 [==============================] - 1s 46ms/step - loss: 2.1784e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0034 - val_mean_absolute_error: 0.0452
# Epoch 53/100
# 28/28 [==============================] - 1s 54ms/step - loss: 2.1637e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0046 - val_mean_absolute_error: 0.0559
# Epoch 54/100
# 28/28 [==============================] - 1s 47ms/step - loss: 1.8625e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0026 - val_mean_absolute_error: 0.0391
# Epoch 55/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.9387e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0019 - val_mean_absolute_error: 0.0332
# Epoch 56/100
# 28/28 [==============================] - 1s 47ms/step - loss: 1.9231e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0019 - val_mean_absolute_error: 0.0325
# Epoch 57/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.8849e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0031 - val_mean_absolute_error: 0.0443
# Epoch 58/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.8231e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0015 - val_mean_absolute_error: 0.0286
# Epoch 59/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.8205e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0042 - val_mean_absolute_error: 0.0530
# Epoch 60/100
# 28/28 [==============================] - 2s 78ms/step - loss: 1.7875e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0035 - val_mean_absolute_error: 0.0482
# Epoch 61/100
# 28/28 [==============================] - 1s 48ms/step - loss: 1.8704e-04 - mean_absolute_error: 0.0101 - val_loss: 9.7199e-04 - val_mean_absolute_error: 0.0228
# Epoch 62/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.9437e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0020 - val_mean_absolute_error: 0.0335
# Epoch 63/100
# 28/28 [==============================] - 1s 47ms/step - loss: 1.7249e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0028 - val_mean_absolute_error: 0.0416
# Epoch 64/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.8014e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0018 - val_mean_absolute_error: 0.0318
# Epoch 65/100
# 28/28 [==============================] - 1s 47ms/step - loss: 1.9426e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0022 - val_mean_absolute_error: 0.0348
# Epoch 66/100
# 28/28 [==============================] - 1s 54ms/step - loss: 1.5707e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0025 - val_mean_absolute_error: 0.0392
# Epoch 67/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.5562e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0014 - val_mean_absolute_error: 0.0274
# Epoch 68/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.6748e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0026 - val_mean_absolute_error: 0.0399
# Epoch 69/100
# 28/28 [==============================] - 2s 77ms/step - loss: 1.5430e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0018 - val_mean_absolute_error: 0.0311
# Epoch 70/100
# 28/28 [==============================] - 1s 47ms/step - loss: 1.5724e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0028 - val_mean_absolute_error: 0.0413
# Epoch 71/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.4946e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0026 - val_mean_absolute_error: 0.0408
# Epoch 72/100
# 28/28 [==============================] - 1s 47ms/step - loss: 1.8462e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0029 - val_mean_absolute_error: 0.0438
# Epoch 73/100
# 28/28 [==============================] - 1s 47ms/step - loss: 1.4493e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0017 - val_mean_absolute_error: 0.0304
# Epoch 74/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.5685e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0017 - val_mean_absolute_error: 0.0313
# Epoch 75/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.4191e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0016 - val_mean_absolute_error: 0.0292
# Epoch 76/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.7874e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0014 - val_mean_absolute_error: 0.0273
# Epoch 77/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.4956e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0018 - val_mean_absolute_error: 0.0319
# Epoch 78/100
# 28/28 [==============================] - 2s 74ms/step - loss: 1.4578e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0019 - val_mean_absolute_error: 0.0337
# Epoch 79/100
# 28/28 [==============================] - 2s 53ms/step - loss: 1.5021e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0028 - val_mean_absolute_error: 0.0437
# Epoch 80/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.3287e-04 - mean_absolute_error: 0.0084 - val_loss: 9.5673e-04 - val_mean_absolute_error: 0.0221
# Epoch 81/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.3979e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0012 - val_mean_absolute_error: 0.0244
# Epoch 82/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.3554e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0020 - val_mean_absolute_error: 0.0316
# Epoch 83/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.3362e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0018 - val_mean_absolute_error: 0.0320
# Epoch 84/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.2760e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0018 - val_mean_absolute_error: 0.0308
# Epoch 85/100
# 28/28 [==============================] - 1s 48ms/step - loss: 1.3769e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0029 - val_mean_absolute_error: 0.0430
# Epoch 86/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.4847e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0016 - val_mean_absolute_error: 0.0315
# Epoch 87/100
# 28/28 [==============================] - 2s 70ms/step - loss: 1.2672e-04 - mean_absolute_error: 0.0079 - val_loss: 9.1711e-04 - val_mean_absolute_error: 0.0222
# Epoch 88/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.3056e-04 - mean_absolute_error: 0.0083 - val_loss: 5.6774e-04 - val_mean_absolute_error: 0.0174
# Epoch 89/100
# 28/28 [==============================] - 1s 49ms/step - loss: 1.2398e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0011 - val_mean_absolute_error: 0.0234
# Epoch 90/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.2557e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0012 - val_mean_absolute_error: 0.0254
# Epoch 91/100
# 28/28 [==============================] - 1s 47ms/step - loss: 1.3450e-04 - mean_absolute_error: 0.0086 - val_loss: 5.0720e-04 - val_mean_absolute_error: 0.0161
# Epoch 92/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.3118e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0019 - val_mean_absolute_error: 0.0339
# Epoch 93/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.2611e-04 - mean_absolute_error: 0.0080 - val_loss: 7.9872e-04 - val_mean_absolute_error: 0.0207
# Epoch 94/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.2288e-04 - mean_absolute_error: 0.0078 - val_loss: 6.4886e-04 - val_mean_absolute_error: 0.0182
# Epoch 95/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.1919e-04 - mean_absolute_error: 0.0079 - val_loss: 6.4872e-04 - val_mean_absolute_error: 0.0185
# Epoch 96/100
# 28/28 [==============================] - 2s 79ms/step - loss: 1.2872e-04 - mean_absolute_error: 0.0080 - val_loss: 3.7827e-04 - val_mean_absolute_error: 0.0143
# Epoch 97/100
# 28/28 [==============================] - 2s 72ms/step - loss: 1.2802e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0012 - val_mean_absolute_error: 0.0268
# Epoch 98/100
# 28/28 [==============================] - 1s 47ms/step - loss: 1.2330e-04 - mean_absolute_error: 0.0080 - val_loss: 7.6945e-04 - val_mean_absolute_error: 0.0207
# Epoch 99/100
# 28/28 [==============================] - 1s 46ms/step - loss: 1.0685e-04 - mean_absolute_error: 0.0074 - val_loss: 0.0011 - val_mean_absolute_error: 0.0257
# Epoch 100/100
# 28/28 [==============================] - 1s 47ms/step - loss: 1.1563e-04 - mean_absolute_error: 0.0075 - val_loss: 9.1287e-04 - val_mean_absolute_error: 0.0230

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 1s 12ms/step
# array([[0.3994494 , 0.40368748],
#        [0.39990905, 0.40391392],
#        [0.39599243, 0.39988244],
#        [0.39934847, 0.40338284],
#        [0.40395543, 0.40807855]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1411.5472, 1416.4302],
#        [1412.3993, 1416.8499],
#        [1405.1382, 1409.3782],
#        [1411.3601, 1415.8656],
#        [1419.901 , 1424.5684]], dtype=float32)

# %% [markdown]
# ## STEP 5 :  VISUALIZING ACTUAL VS PREDICTED DATA

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1411.547241      1416.430176
# 2020-05-28  1396.86  1416.73     1412.399292      1416.849854
# 2020-05-29  1416.94  1428.92     1405.138184      1409.378174
# 2020-06-01  1418.39  1431.82     1411.360107      1415.865601
# 2020-06-02  1430.55  1439.22     1419.901001      1424.568359

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()
